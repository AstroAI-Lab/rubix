# %%
import pickle

# %%
tag_file ="./data/gsf/g2.79e12.01024.halo_1.align_with_star.star.gmm_on_jzjcjpjcexyz.scikit_gmm_full_5clusters_white_tags.decontaminated.split_bulge_in_two.dat"

# %%
tag_data = pickle.load(open(tag_file,'rb'))
component_names = tag_data['tags']

# %%
print("Component names from tag file:")
print(component_names)
# Out:
# Component names from tag file:
# ['Thick disk', 'Bar', 'B/P bulge', 'Thin disk', 'Halo', 'Classical bulge']
