# %%
# NBVAL_SKIP
import os
#os.environ['SPS_HOME'] = '/mnt/storage/annalena_data/sps_fsps'
#os.environ['SPS_HOME'] = '/home/annalena/sps_fsps'
#os.environ['SPS_HOME'] = '/Users/annalena/Documents/GitHub/fsps'
os.environ['SPS_HOME'] = '/export/home/aschaibl/fsps'

# %%
# NBVAL_SKIP
#import jax
#jax.config.update("jax_enable_x64", True)

# %%
#NBVAL_SKIP
config = {
    "pipeline": {"name": "calc_ifu"},
    
    "logger": {
        "log_level": "DEBUG",
        "log_file_path": None,
        "format": "%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    },
    "data": {
        "name": "IllustrisAPI",
        "args": {
            "api_key": os.environ.get("ILLUSTRIS_API_KEY"),
            "particle_type": ["stars"],
            "simulation": "TNG50-1",
            "snapshot": 99,
            "save_data_path": "data",
        },
        
        "load_galaxy_args": {
        "id": 539667,
        "reuse": True,
        },

        "subset": {
            "use_subset": False,
            "subset_size": 2000,
        },
    },
    "simulation": {
        "name": "IllustrisTNG",
        "args": {
            "path": "data/galaxy-id-539667.hdf5",
        },
    
    },
    "output_path": "output",
    "output_modified": False,

    "telescope": {
        "name": "MUSE",
        "psf": {"name": "gaussian", "size": 5, "sigma": 0.5},
        "lsf": {"sigma": 0.5},
        "noise": {"signal_to_noise": 100, "noise_distribution": "normal"},
    },
    "cosmology": {"name": "PLANCK15"},
    "galaxy": {
        "dist_z": 0.1,
        "rotation": {"type": "face-on"},
    },
    "ssp": {
        "template": {"name": "BruzualCharlot2003"},
        "dust": {
                "extinction_model": "Cardelli89",
                "dust_to_gas_ratio": 0.01,
                "dust_to_metals_ratio": 0.4,
                "dust_grain_density": 3.5,
                "Rv": 3.1,
            },
    },
}

# %% [markdown]
# # Bruzual&Charlot

# %%
#NBVAL_SKIP
import jax.numpy as jnp
from rubix.core.pipeline import RubixPipeline
pipe = RubixPipeline(config)

rubixdata = pipe.run()

rubixdata_bruzual = rubixdata
# Out:
# 2025-04-15 14:42:25,772 - rubix - INFO -
#    ___  __  _____  _____  __
#   / _ \/ / / / _ )/  _/ |/_/
#  / , _/ /_/ / _  |/ /_>  <
# /_/|_|\____/____/___/_/|_|
#
#
# 2025-04-15 14:42:25,774 - rubix - INFO - Rubix version: 0.0.post238+gf560922
# 2025-04-15 14:42:25,775 - rubix - INFO - JAX version: 0.5.0
# 2025-04-15 14:42:25,776 - rubix - INFO - Running on [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3), CudaDevice(id=4), CudaDevice(id=5), CudaDevice(id=6), CudaDevice(id=7)] devices
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:26,947 - rubix - INFO - Getting rubix data...
# 2025-04-15 14:42:26,948 - rubix - INFO - Loading data from IllustrisAPI
# 2025-04-15 14:42:26,949 - rubix - DEBUG - Loading galaxy with ID 539667
# 2025-04-15 14:42:26,951 - rubix - DEBUG - Performing GET request from http://www.tng-project.org/api/TNG50-1/snapshots/99/subhalos/539667/cutout.hdf5?stars=Coordinates,GFM_InitialMass,GFM_Metallicity,GFM_StellarFormationTime,Velocities, with parameters None
# 2025-04-15 14:42:30,120 - rubix - DEBUG - Performing GET request from http://www.tng-project.org/api/TNG50-1/snapshots/99/subhalos/539667, with parameters None
# 2025-04-15 14:42:30,350 - rubix - DEBUG - Appending subhalo data for subhalo 539667
# 2025-04-15 14:42:30,707 - rubix - INFO - Loading data into input handler
# 2025-04-15 14:42:30,715 - rubix - DEBUG - Loading data from Illustris file..
# 2025-04-15 14:42:30,715 - rubix - DEBUG - Checking if the fields are present in the file...
# 2025-04-15 14:42:30,716 - rubix - DEBUG - Keys in the file: <KeysViewHDF5 ['Header', 'PartType4', 'SubhaloData']>
# 2025-04-15 14:42:30,717 - rubix - DEBUG - Expected fields: ['Header', 'SubhaloData', 'PartType4', 'PartType0']
# 2025-04-15 14:42:30,718 - rubix - DEBUG - Matching fields: {'PartType4', 'SubhaloData', 'Header'}
# 2025-04-15 14:42:30,728 - rubix - DEBUG - Found 597427 valid particles out of 597427
# 2025-04-15 14:42:31,382 - rubix - DEBUG - Converting Stellar Formation Time to Age
# 2025-04-15 14:42:49,017 - rubix - DEBUG - Converting to Rubix format..
# 2025-04-15 14:42:49,021 - rubix - DEBUG - Checking if the fields are present in the particle data...
# 2025-04-15 14:42:49,022 - rubix - DEBUG - Keys in the particle data: dict_keys(['stars'])
# 2025-04-15 14:42:49,023 - rubix - DEBUG - Expected fields: {'PartType4': 'stars', 'PartType0': 'gas'}
# 2025-04-15 14:42:49,024 - rubix - DEBUG - Matching fields: {'stars'}
# 2025-04-15 14:42:49,025 - rubix - DEBUG - Required fields for stars: ['coords', 'mass', 'metallicity', 'velocity', 'age']
# 2025-04-15 14:42:49,026 - rubix - DEBUG - Available fields in particle_data[stars]: ['coords', 'mass', 'metallicity', 'age', 'velocity']
# 2025-04-15 14:42:49,027 - rubix - INFO - Rubix file saved at output/rubix_galaxy.h5
# 2025-04-15 14:42:49,028 - rubix - DEBUG - Creating Rubix file at path: output/rubix_galaxy.h5
# 2025-04-15 14:42:49,045 - rubix - DEBUG - Converting redshift for galaxy data into
# 2025-04-15 14:42:49,048 - rubix - DEBUG - Converting center for galaxy data into kpc
# 2025-04-15 14:42:49,050 - rubix - DEBUG - Converting halfmassrad_stars for galaxy data into kpc
# 2025-04-15 14:42:49,052 - rubix - DEBUG - Converting coords for particle type stars into kpc
# 2025-04-15 14:42:49,105 - rubix - DEBUG - Converting mass for particle type stars into Msun
# 2025-04-15 14:42:49,235 - rubix - DEBUG - Converting metallicity for particle type stars into
# 2025-04-15 14:42:49,280 - rubix - DEBUG - Converting age for particle type stars into Gyr
# 2025-04-15 14:42:49,307 - rubix - DEBUG - Converting velocity for particle type stars into km/s
# 2025-04-15 14:42:49,433 - rubix - INFO - Rubix file saved at output/rubix_galaxy.h5
# 2025-04-15 14:42:49,619 - rubix - INFO - Centering stars particles
# Converted to Rubix format!
# 2025-04-15 14:42:53,160 - rubix - INFO - Data loaded with 597427 star particles and 0 gas particles.
# 2025-04-15 14:42:53,161 - rubix - INFO - Setting up the pipeline...
# 2025-04-15 14:42:53,162 - rubix - DEBUG - Pipeline Configuration: {'Transformers': {'rotate_galaxy': {'name': 'rotate_galaxy', 'depends_on': None, 'args': [], 'kwargs': {}}, 'filter_particles': {'name': 'filter_particles', 'depends_on': 'rotate_galaxy', 'args': [], 'kwargs': {}}, 'spaxel_assignment': {'name': 'spaxel_assignment', 'depends_on': 'filter_particles', 'args': [], 'kwargs': {}}, 'reshape_data': {'name': 'reshape_data', 'depends_on': 'spaxel_assignment', 'args': [], 'kwargs': {}}, 'calculate_spectra': {'name': 'calculate_spectra', 'depends_on': 'reshape_data', 'args': [], 'kwargs': {}}, 'scale_spectrum_by_mass': {'name': 'scale_spectrum_by_mass', 'depends_on': 'calculate_spectra', 'args': [], 'kwargs': {}}, 'doppler_shift_and_resampling': {'name': 'doppler_shift_and_resampling', 'depends_on': 'scale_spectrum_by_mass', 'args': [], 'kwargs': {}}, 'calculate_datacube': {'name': 'calculate_datacube', 'depends_on': 'doppler_shift_and_resampling', 'args': [], 'kwargs': {}}, 'convolve_psf': {'name': 'convolve_psf', 'depends_on': 'calculate_datacube', 'args': [], 'kwargs': {}}, 'convolve_lsf': {'name': 'convolve_lsf', 'depends_on': 'convolve_psf', 'args': [], 'kwargs': {}}, 'apply_noise': {'name': 'apply_noise', 'depends_on': 'convolve_lsf', 'args': [], 'kwargs': {}}}}
# 2025-04-15 14:42:53,163 - rubix - DEBUG - Roataion Type found: Face-on
# 2025-04-15 14:42:53,165 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:53,191 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:54,029 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:54,066 - rubix - INFO - Getting cosmology...
# 2025-04-15 14:42:54,100 - rubix - DEBUG - Method not defined, using default method: cubic
# 2025-04-15 14:42:54,123 - rubix - DEBUG - Method not defined, using default method: cubic
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:54,250 - rubix - DEBUG - SSP Wave: (842,)
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:54,292 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:42:55,097 - rubix - INFO - Assembling the pipeline...
# 2025-04-15 14:42:55,099 - rubix - INFO - Compiling the expressions...
# 2025-04-15 14:42:55,100 - rubix - INFO - Running the pipeline on the input data...
# 2025-04-15 14:42:55,150 - rubix - INFO - Rotating galaxy with alpha=0.0, beta=0.0, gamma=0.0
# 2025-04-15 14:42:55,388 - rubix - INFO - Filtering particles outside the aperture...
# 2025-04-15 14:42:55,399 - rubix - INFO - Assigning particles to spaxels...
# 2025-04-15 14:42:55,432 - rubix - WARNING - Attribute value of datacube is None or not an array
# 2025-04-15 14:42:55,441 - rubix - WARNING - Attribute value of spectra is None or not an array
# 2025-04-15 14:42:55,443 - rubix - WARNING - Attribute value of tree_flatten is None or not an array
# 2025-04-15 14:42:55,443 - rubix - WARNING - Attribute value of tree_unflatten is None or not an array
# 2025-04-15 14:42:55,444 - rubix - INFO - Calculating IFU cube...
# 2025-04-15 14:42:55,445 - rubix - DEBUG - Input shapes: Metallicity: 8, Age: 8
# 2025-04-15 14:42:55,858 - rubix - DEBUG - Calculation Finished! Spectra shape: (74679, 842)
# 2025-04-15 14:42:55,861 - rubix - INFO - Scaling Spectra by Mass...
# 2025-04-15 14:42:55,870 - rubix - INFO - Doppler shifting and resampling spectra...
# 2025-04-15 14:42:55,871 - rubix - DEBUG - Doppler Shifted SSP Wave: (8, 74679, 842)
# 2025-04-15 14:42:55,872 - rubix - DEBUG - Telescope Wave Seq: (3721,)
# 2025-04-15 14:42:55,994 - rubix - INFO - Calculating Data Cube...
# 2025-04-15 14:42:55,999 - rubix - DEBUG - Datacube Shape: (25, 25, 3721)
# 2025-04-15 14:42:56,000 - rubix - INFO - Convolving with PSF...
# 2025-04-15 14:42:56,004 - rubix - INFO - Convolving with LSF...
# 2025-04-15 14:42:56,013 - rubix - INFO - Applying noise to datacube with signal to noise ratio: 100 and noise distribution: normal
# /export/home/aschaibl/miniconda3/envs/rubix/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1873: UserWarning: The jitted function <unnamed wrapped function> includes a pmap. Using jit-of-pmap can lead to inefficient data movement, as the outer jit does not preserve sharded data representations and instead collects input and output arrays onto a single device. Consider removing the outer jit unless you know what you're doing. See https://github.com/jax-ml/jax/issues/2926. Or use jax.experimental.shard_map instead of pmap under jit compilation.
#   warnings.warn(
# 2025-04-15 14:43:01.813911: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 3.40GiB (3652249076 bytes) by rematerialization; only reduced to 25.91GiB (27822151840 bytes), down from 25.92GiB (27829321284 bytes) originally
# 2025-04-15 14:43:18.683542: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.683800: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ***********************************************************************_____________________________
# E0415 14:43:18.683836 1943266 pjrt_stream_executor_client.cc:3045] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.703502: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_3_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.703682: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.703712 1943275 pjrt_stream_executor_client.cc:3045] Execution of replica 3 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.730803: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_4_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.730989: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.731020 1943278 pjrt_stream_executor_client.cc:3045] Execution of replica 4 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.751945: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_7_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.752120: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.752158 1943287 pjrt_stream_executor_client.cc:3045] Execution of replica 7 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.776151: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_5_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.776335: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.776367 1943281 pjrt_stream_executor_client.cc:3045] Execution of replica 5 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.797270: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_6_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.797455: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.797485 1943284 pjrt_stream_executor_client.cc:3045] Execution of replica 6 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.820373: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_2_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.820557: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.820590 1943272 pjrt_stream_executor_client.cc:3045] Execution of replica 2 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# 2025-04-15 14:43:18.838824: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_1_bfc) ran out of memory trying to allocate 6.45GiB (rounded to 6928126976)requested by op
# 2025-04-15 14:43:18.839001: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **********************************************************************______________________________
# E0415 14:43:18.839033 1943269 pjrt_stream_executor_client.cc:3045] Execution of replica 1 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes. [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[4], line 6
#       3 from rubix.core.pipeline import RubixPipeline
#       4 pipe = RubixPipeline(config)
# ----> 6 rubixdata = pipe.run()
#       8 rubixdata_bruzual = rubixdata
#
# File ~/rubix/rubix/core/pipeline.py:164, in RubixPipeline.run(self)
#     162 # Running the pipeline
#     163 self.logger.info("Running the pipeline on the input data...")
# --> 164 output = self.func(self.data)
#     166 block_until_ready(output)
#     167 time_end = time.time()
#
#     [... skipping hidden 5 frame]
#
# File ~/miniconda3/envs/rubix/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1298, in ExecuteReplicated.__call__(self, *args)
#    1296   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1297 else:
# -> 1298   results = self.xla_executable.execute_sharded(input_bufs)
#    1300 if dispatch.needs_check_special():
#    1301   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 6928126952 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).

# %% [markdown]
# # FSPS

# %%
# NBVAL_SKIP
config["ssp"]["template"]["name"] = "FSPS"

pipe = RubixPipeline(config)

rubixdata = pipe.run()
rubixdata_fsps = rubixdata
# Out:
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,148 - rubix - INFO - Getting rubix data...
# 2025-04-15 14:41:00,149 - rubix - INFO - Rubix galaxy file already exists, skipping conversion
# 2025-04-15 14:41:00,208 - rubix - INFO - Centering stars particles
# 2025-04-15 14:41:00,255 - rubix - WARNING - The Subset value is set in config. Using only subset of size 2000 for stars
# 2025-04-15 14:41:00,256 - rubix - INFO - Data loaded with 2000 star particles and 0 gas particles.
# 2025-04-15 14:41:00,371 - rubix - INFO - Setting up the pipeline...
# 2025-04-15 14:41:00,372 - rubix - DEBUG - Pipeline Configuration: {'Transformers': {'rotate_galaxy': {'name': 'rotate_galaxy', 'depends_on': None, 'args': [], 'kwargs': {}}, 'filter_particles': {'name': 'filter_particles', 'depends_on': 'rotate_galaxy', 'args': [], 'kwargs': {}}, 'spaxel_assignment': {'name': 'spaxel_assignment', 'depends_on': 'filter_particles', 'args': [], 'kwargs': {}}, 'reshape_data': {'name': 'reshape_data', 'depends_on': 'spaxel_assignment', 'args': [], 'kwargs': {}}, 'calculate_spectra': {'name': 'calculate_spectra', 'depends_on': 'reshape_data', 'args': [], 'kwargs': {}}, 'scale_spectrum_by_mass': {'name': 'scale_spectrum_by_mass', 'depends_on': 'calculate_spectra', 'args': [], 'kwargs': {}}, 'doppler_shift_and_resampling': {'name': 'doppler_shift_and_resampling', 'depends_on': 'scale_spectrum_by_mass', 'args': [], 'kwargs': {}}, 'calculate_datacube': {'name': 'calculate_datacube', 'depends_on': 'doppler_shift_and_resampling', 'args': [], 'kwargs': {}}, 'convolve_psf': {'name': 'convolve_psf', 'depends_on': 'calculate_datacube', 'args': [], 'kwargs': {}}, 'convolve_lsf': {'name': 'convolve_lsf', 'depends_on': 'convolve_psf', 'args': [], 'kwargs': {}}, 'apply_noise': {'name': 'apply_noise', 'depends_on': 'convolve_lsf', 'args': [], 'kwargs': {}}}}
# 2025-04-15 14:41:00,373 - rubix - DEBUG - Roataion Type found: Face-on
# 2025-04-15 14:41:00,376 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,418 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,467 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,506 - rubix - INFO - Getting cosmology...
# 2025-04-15 14:41:00,618 - rubix - DEBUG - Method not defined, using default method: cubic
# 2025-04-15 14:41:00,733 - rubix - DEBUG - Method not defined, using default method: cubic
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,896 - rubix - DEBUG - SSP Wave: (5994,)
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:00,953 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:01,047 - rubix - INFO - Assembling the pipeline...
# 2025-04-15 14:41:01,049 - rubix - INFO - Compiling the expressions...
# 2025-04-15 14:41:01,050 - rubix - INFO - Running the pipeline on the input data...
# 2025-04-15 14:41:01,080 - rubix - INFO - Rotating galaxy with alpha=0.0, beta=0.0, gamma=0.0
# 2025-04-15 14:41:01,282 - rubix - INFO - Filtering particles outside the aperture...
# 2025-04-15 14:41:01,289 - rubix - INFO - Assigning particles to spaxels...
# 2025-04-15 14:41:01,295 - rubix - WARNING - Attribute value of datacube is None or not an array
# 2025-04-15 14:41:01,301 - rubix - WARNING - Attribute value of spectra is None or not an array
# 2025-04-15 14:41:01,302 - rubix - WARNING - Attribute value of tree_flatten is None or not an array
# 2025-04-15 14:41:01,302 - rubix - WARNING - Attribute value of tree_unflatten is None or not an array
# 2025-04-15 14:41:01,303 - rubix - INFO - Calculating IFU cube...
# 2025-04-15 14:41:01,304 - rubix - DEBUG - Input shapes: Metallicity: 8, Age: 8
# 2025-04-15 14:41:01,311 - rubix - DEBUG - Calculation Finished! Spectra shape: (250, 5994)
# 2025-04-15 14:41:01,314 - rubix - INFO - Scaling Spectra by Mass...
# 2025-04-15 14:41:01,319 - rubix - INFO - Doppler shifting and resampling spectra...
# 2025-04-15 14:41:01,320 - rubix - DEBUG - Doppler Shifted SSP Wave: (8, 250, 5994)
# 2025-04-15 14:41:01,321 - rubix - DEBUG - Telescope Wave Seq: (3721,)
# 2025-04-15 14:41:01,522 - rubix - INFO - Calculating Data Cube...
# 2025-04-15 14:41:01,530 - rubix - DEBUG - Datacube Shape: (25, 25, 3721)
# 2025-04-15 14:41:01,531 - rubix - INFO - Convolving with PSF...
# 2025-04-15 14:41:01,536 - rubix - INFO - Convolving with LSF...
# 2025-04-15 14:41:01,544 - rubix - INFO - Applying noise to datacube with signal to noise ratio: 100 and noise distribution: normal
# /export/home/aschaibl/miniconda3/envs/rubix/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1873: UserWarning: The jitted function <unnamed wrapped function> includes a pmap. Using jit-of-pmap can lead to inefficient data movement, as the outer jit does not preserve sharded data representations and instead collects input and output arrays onto a single device. Consider removing the outer jit unless you know what you're doing. See https://github.com/jax-ml/jax/issues/2926. Or use jax.experimental.shard_map instead of pmap under jit compilation.
#   warnings.warn(
# 2025-04-15 14:41:16,324 - rubix - INFO - Pipeline run completed in 15.95 seconds.

# %% [markdown]
# # MaStar

# %%
# NBVAL_SKIP
config["ssp"]["template"]["name"] = "Mastar_CB19_SLOG_1_5"

pipe = RubixPipeline(config)

rubixdata = pipe.run()
rubixdata_mastar = rubixdata
# Out:
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:18,382 - rubix - INFO - Getting rubix data...
# 2025-04-15 14:41:18,388 - rubix - INFO - Rubix galaxy file already exists, skipping conversion
# 2025-04-15 14:41:18,456 - rubix - INFO - Centering stars particles
# 2025-04-15 14:41:18,512 - rubix - WARNING - The Subset value is set in config. Using only subset of size 2000 for stars
# 2025-04-15 14:41:18,513 - rubix - INFO - Data loaded with 2000 star particles and 0 gas particles.
# 2025-04-15 14:41:18,766 - rubix - INFO - Setting up the pipeline...
# 2025-04-15 14:41:18,768 - rubix - DEBUG - Pipeline Configuration: {'Transformers': {'rotate_galaxy': {'name': 'rotate_galaxy', 'depends_on': None, 'args': [], 'kwargs': {}}, 'filter_particles': {'name': 'filter_particles', 'depends_on': 'rotate_galaxy', 'args': [], 'kwargs': {}}, 'spaxel_assignment': {'name': 'spaxel_assignment', 'depends_on': 'filter_particles', 'args': [], 'kwargs': {}}, 'reshape_data': {'name': 'reshape_data', 'depends_on': 'spaxel_assignment', 'args': [], 'kwargs': {}}, 'calculate_spectra': {'name': 'calculate_spectra', 'depends_on': 'reshape_data', 'args': [], 'kwargs': {}}, 'scale_spectrum_by_mass': {'name': 'scale_spectrum_by_mass', 'depends_on': 'calculate_spectra', 'args': [], 'kwargs': {}}, 'doppler_shift_and_resampling': {'name': 'doppler_shift_and_resampling', 'depends_on': 'scale_spectrum_by_mass', 'args': [], 'kwargs': {}}, 'calculate_datacube': {'name': 'calculate_datacube', 'depends_on': 'doppler_shift_and_resampling', 'args': [], 'kwargs': {}}, 'convolve_psf': {'name': 'convolve_psf', 'depends_on': 'calculate_datacube', 'args': [], 'kwargs': {}}, 'convolve_lsf': {'name': 'convolve_lsf', 'depends_on': 'convolve_psf', 'args': [], 'kwargs': {}}, 'apply_noise': {'name': 'apply_noise', 'depends_on': 'convolve_lsf', 'args': [], 'kwargs': {}}}}
# 2025-04-15 14:41:18,769 - rubix - DEBUG - Roataion Type found: Face-on
# 2025-04-15 14:41:18,772 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:18,811 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:18,859 - rubix - INFO - Calculating spatial bin edges...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:18,900 - rubix - INFO - Getting cosmology...
# 2025-04-15 14:41:20,925 - rubix - DEBUG - Method not defined, using default method: cubic
# 2025-04-15 14:41:22,747 - rubix - DEBUG - Method not defined, using default method: cubic
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:24,751 - rubix - DEBUG - SSP Wave: (5333,)
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:24,795 - rubix - INFO - Getting cosmology...
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# /export/home/aschaibl/rubix/rubix/telescope/factory.py:24: UserWarning: No telescope config provided, using default stored in /export/home/aschaibl/rubix/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2025-04-15 14:41:24,890 - rubix - INFO - Assembling the pipeline...
# 2025-04-15 14:41:24,891 - rubix - INFO - Compiling the expressions...
# 2025-04-15 14:41:24,893 - rubix - INFO - Running the pipeline on the input data...
# 2025-04-15 14:41:24,925 - rubix - INFO - Rotating galaxy with alpha=0.0, beta=0.0, gamma=0.0
# 2025-04-15 14:41:25,136 - rubix - INFO - Filtering particles outside the aperture...
# 2025-04-15 14:41:25,144 - rubix - INFO - Assigning particles to spaxels...
# 2025-04-15 14:41:25,149 - rubix - WARNING - Attribute value of datacube is None or not an array
# 2025-04-15 14:41:25,153 - rubix - WARNING - Attribute value of spectra is None or not an array
# 2025-04-15 14:41:25,154 - rubix - WARNING - Attribute value of tree_flatten is None or not an array
# 2025-04-15 14:41:25,155 - rubix - WARNING - Attribute value of tree_unflatten is None or not an array
# 2025-04-15 14:41:25,155 - rubix - INFO - Calculating IFU cube...
# 2025-04-15 14:41:25,156 - rubix - DEBUG - Input shapes: Metallicity: 8, Age: 8
# 2025-04-15 14:41:25,162 - rubix - DEBUG - Calculation Finished! Spectra shape: (250, 5333)
# 2025-04-15 14:41:25,163 - rubix - INFO - Scaling Spectra by Mass...
# 2025-04-15 14:41:25,167 - rubix - INFO - Doppler shifting and resampling spectra...
# 2025-04-15 14:41:25,168 - rubix - DEBUG - Doppler Shifted SSP Wave: (8, 250, 5333)
# 2025-04-15 14:41:25,169 - rubix - DEBUG - Telescope Wave Seq: (3721,)
# 2025-04-15 14:41:25,303 - rubix - INFO - Calculating Data Cube...
# 2025-04-15 14:41:25,308 - rubix - DEBUG - Datacube Shape: (25, 25, 3721)
# 2025-04-15 14:41:25,309 - rubix - INFO - Convolving with PSF...
# 2025-04-15 14:41:25,313 - rubix - INFO - Convolving with LSF...
# 2025-04-15 14:41:25,318 - rubix - INFO - Applying noise to datacube with signal to noise ratio: 100 and noise distribution: normal
# /export/home/aschaibl/miniconda3/envs/rubix/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1873: UserWarning: The jitted function <unnamed wrapped function> includes a pmap. Using jit-of-pmap can lead to inefficient data movement, as the outer jit does not preserve sharded data representations and instead collects input and output arrays onto a single device. Consider removing the outer jit unless you know what you're doing. See https://github.com/jax-ml/jax/issues/2926. Or use jax.experimental.shard_map instead of pmap under jit compilation.
#   warnings.warn(
# 2025-04-15 14:41:33,079 - rubix - INFO - Pipeline run completed in 14.31 seconds.

# %% [markdown]
# # Convert luminosity to flux

# %%
# NBVAL_SKIP
from rubix.spectra.ifu import convert_luminoisty_to_flux
from rubix.cosmology import PLANCK15

observation_lum_dist = PLANCK15.luminosity_distance_to_z(config["galaxy"]["dist_z"])
observation_z = config["galaxy"]["dist_z"]
pixel_size = 1.0
spectra_bruzual = convert_luminoisty_to_flux(rubixdata_bruzual.stars.datacube, observation_lum_dist, observation_z, pixel_size)
spectra_fsps = convert_luminoisty_to_flux(rubixdata_fsps.stars.datacube, observation_lum_dist, observation_z, pixel_size)
spectra_mastar = convert_luminoisty_to_flux(rubixdata_mastar.stars.datacube, observation_lum_dist, observation_z, pixel_size)

# %% [markdown]
# # Visualize the mock data

# %%
# NBVAL_SKIP
import jax.numpy as jnp
import matplotlib.pyplot as plt

# Assuming wave and spectra are already defined
wave = pipe.telescope.wave_seq
spectra = rubixdata_mastar.stars.datacube

# Define the spaxel index to highlight
spaxel_x, spaxel_y = 12, 12
spaxel_x2, spaxel_y2 = 12, 14
spaxel_x3, spaxel_y3 = 12, 16
spaxel_x4, spaxel_y4 = 16, 12

# Prepare the visible range data
visible_indices = jnp.where((wave >= 4000) & (wave <= 8000))
visible_spectra = spectra[:, :, visible_indices[0]]
image = jnp.sum(visible_spectra, axis=2)

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the spectrum on the left
axes[0].plot(wave, spectra[spaxel_x, spaxel_y, :], label=f"Spaxel [{spaxel_x}, {spaxel_y}]")
axes[0].plot(wave, spectra[spaxel_x2, spaxel_y2, :], label=f"Spaxel [{spaxel_x2}, {spaxel_y2}]")
axes[0].plot(wave, spectra[spaxel_x3, spaxel_y3, :], label=f"Spaxel [{spaxel_x3}, {spaxel_y3}]")
axes[0].plot(wave, spectra[spaxel_x4, spaxel_y4, :], label=f"Spaxel [{spaxel_x4}, {spaxel_y4}]")
axes[0].set_title("Spectrum of Spaxel [12, 12]")
axes[0].set_xlabel("Wavelength [Å]")
axes[0].set_ylabel("Flux")
axes[0].legend()

# Plot the image on the right
im = axes[1].imshow(image, origin="lower", cmap="inferno")
axes[1].scatter(spaxel_y, spaxel_x, color="red", marker="*", s=100, label="Spaxel [12, 12]")  # Mark the spaxel
axes[1].scatter(spaxel_y2, spaxel_x2, color="blue", marker="*", s=100, label="Spaxel [12, 14]")  # Mark the spaxel
axes[1].scatter(spaxel_y3, spaxel_x3, color="green", marker="*", s=100, label="Spaxel [12, 16]")  # Mark the spaxel
axes[1].scatter(spaxel_y4, spaxel_x4, color="orange", marker="*", s=100, label="Spaxel [16, 12]")  # Mark the spaxel
axes[1].set_title("Spatial Image from Data Cube")
axes[1].legend()
cbar = fig.colorbar(im, ax=axes[1], orientation="vertical", label="Integrated Flux")

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
# NBVAL_SKIP
import jax.numpy as jnp
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.gridspec import GridSpec

# Assuming wave, spectra, image, image2, and image3 are defined
wave = pipe.telescope.wave_seq
#spectra1 = rubixdata_bruzual.stars.datacube
#spectra2 = rubixdata_fsps.stars.datacube
#spectra3 = rubixdata_mastar.stars.datacube
spectra1 = spectra_bruzual
spectra2 = spectra_fsps
spectra3 = spectra_mastar

# Spaxel to highlight
spaxel_x, spaxel_y = 12, 12 #75, 75
spaxel_x2, spaxel_y2 = 12, 14 #75, 95
spaxel_x3, spaxel_y3 = 12, 16 #75, 105

# Example images (replace with your data)
visible_indices = jnp.where((wave >= 4000) & (wave <= 8000))
visible_spectra1 = spectra1[:, :, visible_indices[0]]
visible_spectra2 = spectra2[:, :, visible_indices[0]]
visible_spectra3 = spectra3[:, :, visible_indices[0]]
image1 = jnp.sum(visible_spectra1, axis=2)  # Bruzual image
image2 = jnp.sum(visible_spectra2, axis=2)  # FSPS image
image3 = jnp.sum(visible_spectra3, axis=2)  # MaStar image

vmin = 0

# Create figure with GridSpec
fig = plt.figure(figsize=(16, 14))
gs = GridSpec(4, 3, height_ratios=[0.7, 0.3, 0.3, 0.3], hspace=0.4)

sum1 = jnp.sum(spectra1[spaxel_x, spaxel_y, :])
sum2 = jnp.sum(spectra2[spaxel_x, spaxel_y, :])
sum3 = jnp.sum(spectra3[spaxel_x, spaxel_y, :])
print(sum1, sum2, sum3)

# First row: images
ax1 = fig.add_subplot(gs[0, 0])
im1 = ax1.imshow(image1, origin="lower", cmap="inferno")#, vmin=vmin, vmax=1.8e7)#, norm=LogNorm())
ax1.scatter(spaxel_y, spaxel_x, color="red", marker="*", s=100, label="Spaxel [12, 12]")
ax1.scatter(spaxel_y2, spaxel_x2, color="blue", marker="*", s=100, label="Spaxel [12, 14]")
ax1.scatter(spaxel_y3, spaxel_x3, color="green", marker="*", s=100, label="Spaxel [12, 16]")
ax1.set_title("Bruzual&Charlot 2003")
ax1.legend()
fig.colorbar(im1, ax=ax1, orientation="vertical")

ax2 = fig.add_subplot(gs[0, 1])
im2 = ax2.imshow(image2, origin="lower", cmap="inferno")#, vmin=vmin, vmax=1.8e5)#, norm=LogNorm())
ax2.scatter(spaxel_y, spaxel_x, color="red", marker="*", s=100)
ax2.scatter(spaxel_y2, spaxel_x2, color="blue", marker="*", s=100)
ax2.scatter(spaxel_y3, spaxel_x3, color="green", marker="*", s=100)
ax2.set_title("FSPS")
fig.colorbar(im2, ax=ax2, orientation="vertical")

ax3 = fig.add_subplot(gs[0, 2])
im3 = ax3.imshow(image3, origin="lower", cmap="inferno")#, vmin=vmin, vmax=0.9e6)#, norm=LogNorm())
ax3.scatter(spaxel_y, spaxel_x, color="red", marker="*", s=100)
ax3.scatter(spaxel_y2, spaxel_x2, color="blue", marker="*", s=100)
ax3.scatter(spaxel_y3, spaxel_x3, color="green", marker="*", s=100)
ax3.set_title("MaStar")
fig.colorbar(im3, ax=ax3, orientation="vertical")

# Second row: spectrum
ax4 = fig.add_subplot(gs[1, :])  # Full-width spectrum
ax4.plot(wave, spectra1[spaxel_x, spaxel_y, :], color="red")
ax4.plot(wave, spectra1[spaxel_x2, spaxel_y2, :], color="blue")
ax4.plot(wave, spectra1[spaxel_x3, spaxel_y3, :], color="green")
#ax4.plot(wave, spectra2[spaxel_x, spaxel_y, :], label=f"Spaxel [{spaxel_x}, {spaxel_y}], FSPS")
#ax4.plot(wave, spectra3[spaxel_x, spaxel_y, :], label=f"Spaxel [{spaxel_x}, {spaxel_y}], MaStar")
ax4.set_title(f"Spectrum of Spaxels from Bruzual")
ax4.set_xlabel("Wavelength [Å]")
ax4.set_ylabel("Flux [erg/s/cm2/Å]")
#ax4.set_yscale("log")
#ax4.legend()

ax5 = fig.add_subplot(gs[2, :])  # Full-width spectrum
ax5.plot(wave, spectra2[spaxel_x, spaxel_y, :], color="red")
ax5.plot(wave, spectra2[spaxel_x2, spaxel_y2, :], color="blue")
ax5.plot(wave, spectra2[spaxel_x3, spaxel_y3, :], color="green")
ax5.set_title(f"Spectrum of Spaxels from FSPS")
ax5.set_xlabel("Wavelength [Å]")
ax5.set_ylabel("Flux [erg/s/cm2/Å]")
#ax4.set_yscale("log")
#ax5.legend()

ax6 = fig.add_subplot(gs[3, :])  # Full-width spectrum
ax6.plot(wave, spectra3[spaxel_x, spaxel_y, :], color="red")
ax6.plot(wave, spectra3[spaxel_x2, spaxel_y2, :], color="blue")
ax6.plot(wave, spectra3[spaxel_x3, spaxel_y3, :], color="green")
ax6.set_title(f"Spectrum of Spaxels from MaStar")
ax6.set_xlabel("Wavelength [Å]")
ax6.set_ylabel("Flux [erg/s/cm2/Å]")
#ax4.set_yscale("log")
#ax6.legend()

# Adjust layout and show
plt.tight_layout()
plt.savefig("output/ssp_compare_spectra_100000.png")
plt.show()
# Out:
# 1.9239424e-15 3.8448162e-17 2.0598277e-16
# /tmp/ipykernel_1941411/3102457623.py:101: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
