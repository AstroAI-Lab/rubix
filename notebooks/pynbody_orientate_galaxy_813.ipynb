# %%
import pynbody

# %%
galaxy_id = "g8.13e11"
path = f'/home/_data/nihao/nihao_classic/{galaxy_id}/{galaxy_id}.01024'

# %%
sim = pynbody.load(path)
sim.physical_units()

# %%
halos = sim.halos()
halo = halos[0]

# %%
#ang_mom_vec = pynbody.analysis.angmom.ang_mom_vec(halo.s)
#rotation_matrix = pynbody.analysis.angmom.calc_faceon_matrix(ang_mom_vec)

# %%
pynbody.analysis.sideon(halo.s)
#halo.rotate_y(80)
pynbody.plot.image(halo.s, width=10, cmap='Blues')

# %%
#halo.rotate_z(25)
halo.rotate_y(-40)

pynbody.plot.image(halo.s, width=10, cmap='Blues')

# %%
#pynbody.analysis.faceon(halo)
halo.rotate_x(90)
pynbody.plot.image(halo.s, width=10, cmap='Blues')
