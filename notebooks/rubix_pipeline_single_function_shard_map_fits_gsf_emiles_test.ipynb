# %%
import os

galaxy_id = os.environ.get("GALAXY_ID")
component_str = os.environ.get("COMPONENT", None)
split_file = os.environ.get("SPLIT_FILE", "")

print("Notebook gestartet mit:")
print("GALAXY_ID =", galaxy_id)
print("COMPONENT =", component_str)
print("SPLIT_FILE =", split_file)
# Out:
# Notebook gestartet mit:
# GALAXY_ID = None
# COMPONENT = None
# SPLIT_FILE =

# %%
galaxy_id = "g2.79e12"
component_str = ["Bar"]
split_file = "./data/gsf/g2.79e12.01024.halo_1.align_with_star.star.gmm_on_jzjcjpjcexyz.scikit_gmm_full_5clusters_white.decontaminated.split_bulge_in_two.dat"

# %%
if component_str is None or component_str == "" or component_str == "None":
    component = None
else:
    # split by comma and strip whitespace
    #component = [c.strip() for c in component_str.split(",")]
    component = component_str

# %%
# This code is run on the emiles-template branch
# This code is run on jarvis

# %%
from jax import config
#config.update("jax_enable_x64", True)
config.update('jax_num_cpu_devices', 8)

# %%
#NBVAL_SKIP
import os

# Tell XLA to fake 2 host CPU devices
#os.environ['XLA_FLAGS'] = '--xla_force_host_platform_device_count=3'

# Only make GPU 0 and GPU 1 visible to JAX:
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'

#os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]   = "false"

import jax

# Now JAX will list two CpuDevice entries
print(jax.devices())
# → [CpuDevice(id=0), CpuDevice(id=1)]
# Out:
# [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7)]

# %%
# NBVAL_SKIP
#import os
#  os.environ['SPS_HOME'] = '/mnt/storage/annalena_data/sps_fsps'
#os.environ['SPS_HOME'] = '/home/annalena/sps_fsps'
#os.environ['SPS_HOME'] = '/Users/annalena/Documents/GitHub/fsps'
#os.environ['SPS_HOME'] = '/export/home/aschaibl/fsps'
os.environ['SPS_HOME'] = '/home/annalena_data/sps_fsps'

# %% [markdown]
# ## Step 1: Config

# %%
#NBVAL_SKIP
import matplotlib.pyplot as plt
from rubix.core.pipeline import RubixPipeline 
import os

#galaxy_id = "g5.02e11"
#component = "ThinDisk" #None #"ThinDisk" #"ThickDisk" #"Halo" #"PseudoBulge"
#split_file = "./data/gsf/g5.02e11.01024.gmm_full_white_jzjcejpjc_5clusters_2018tags.dat"

config_NIHAO = {
    "pipeline":{"name": "calc_ifu_memory"},
    
    "logger": {
        "log_level": "DEBUG",
        "log_file_path": None,
        "format": "%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    },
    "data": {
        "name": "NihaoHandler",
        "args": {
            "particle_type": ["stars"],
            "save_data_path": "data",
            "snapshot": "1024",
        },
        "load_galaxy_args": {"reuse": True, "id": galaxy_id},
        "subset": {"use_subset": True, "subset_size": 2000},
    },
    "simulation": {
        "name": "NIHAO",
        "args": {
            #"path": f'/export/home/aschaibl/502e11/{galaxy_id}.01024',
            #"halo_path": f'/export/home/aschaibl/502e11/{galaxy_id}.01024.z0.000.AHF_halos',
            "path": f'/home/_data/nihao/nihao_classic/{galaxy_id}/{galaxy_id}.01024',
            "halo_path": f'/home/_data/nihao/nihao_classic/{galaxy_id}/{galaxy_id}.01024.z0.000.AHF_halos',
            "halo_id": 0,
        },
    },
    "output_path": "output",

    "telescope":
        {"name": "MUSE_WFM",
         "psf": {"name": "gaussian", "size": 5, "sigma": 0.6},
         "lsf": {"sigma": 0.5},
         "noise": {"signal_to_noise": 100,"noise_distribution": "normal"},},
    "cosmology":
        {"name": "PLANCK15"},
        
    "galaxy":
        {"dist_z": 0.01,
         "rotation": {"type": "matrix"}, #{"alpha": 0.0, "beta": 0.0, "gamma":0.0},
         "component": component,#None, #["ThinDisk", "ThickDisk", "Halo", "PseudoBulge"], #None,
         "component_file": split_file, 
        },
        
    "ssp": {
        "template": {
            "name": "EMILES" #"Mastar_CB19_SLOG_1_5" #"FSPS" #"BruzualCharlot2003" #"Mastar_CB19_SLOG_1_5"
        },
        "dust": {
                "extinction_model": "Cardelli89",
                "dust_to_gas_ratio": 0.01,
                "dust_to_metals_ratio": 0.4,
                "dust_grain_density": 3.5,
                "Rv": 3.1,
            },
    },        
}
# Out:
# 2026-02-02 10:45:45,380 - rubix - INFO -
#    ___  __  _____  _____  __
#   / _ \/ / / / _ )/  _/ |/_/
#  / , _/ /_/ / _  |/ /_>  <
# /_/|_|\____/____/___/_/|_|
#
#
# 2026-02-02 10:45:45,381 - rubix - INFO - Rubix version: 0.0.post484+g76a35b407.d20260128
# 2026-02-02 10:45:45,382 - rubix - INFO - JAX version: 0.7.2
# 2026-02-02 10:45:45,382 - rubix - INFO - Running on [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7)] devices
# 2026-02-02 10:45:45,383 - rubix - WARNING - python-fsps is not installed. Please install it to use this function. Install using pip install fsps and check the installation page: https://dfm.io/python-fsps/current/installation/ for more details. Especially, make sure to set all necessary environment variables.

# %% [markdown]
# ## Step 2: Pipeline yaml

# %% [markdown]
# ## Step 3: Run the pipeline
#
# After defining the `config` and the `pipeline_config` you can simply run the whole pipeline by these two lines of code.

# %%
#NBVAL_SKIP
pipe = RubixPipeline(config_NIHAO)
# Out:
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(

# %%
#NBVAL_SKIP

inputdata = pipe.prepare_data()
rubixdata = pipe.run_sharded(inputdata)
# Out:
# 2026-02-02 10:45:46,214 - rubix - INFO - Getting rubix data...
# 2026-02-02 10:45:46,215 - rubix - INFO - Loading data into input handler
# 2026-02-02 10:45:46,215 - rubix - INFO - Using PynbodyHandler to load a NIHAO galaxy
# 2026-02-02 10:45:46,218 - rubix - INFO - Galaxy redshift (dist_z) set to: 0.01
# 2026-02-02 10:45:46,234 - rubix - INFO - Simulation snapshot loaded from halo 0
# 2026-02-02 10:45:46,379 - rubix - INFO - Halo data loaded.
# 2026-02-02 10:45:52,662 - rubix - INFO - Rotation matrix calculated and saved to '/notebooks/data/rotation_matrix.npy'.
# 2026-02-02 10:45:52,663 - rubix - INFO - Loaded halo data for halo ID 0 with 3099962 particles.
# 2026-02-02 10:45:52,664 - rubix - INFO - Loading components from file: ./data/gsf/g2.79e12.01024.halo_1.align_with_star.star.gmm_on_jzjcjpjcexyz.scikit_gmm_full_5clusters_white.decontaminated.split_bulge_in_two.dat.
# 2026-02-02 10:45:52,664 - rubix - INFO - Filtering components by: ['Bar'].
# 2026-02-02 10:45:52,759 - rubix - INFO - Filtering components by tags (resolved): ['Bar']
# 2026-02-02 10:45:52,957 - rubix - INFO - Filtered to components ['Bar'] (994189 particles out of 3099962).
# 2026-02-02 10:45:52,977 - rubix - DEBUG - 994189 particles for stars loaded from 'tform'
# 2026-02-02 10:45:52,983 - rubix - DEBUG - 994189 particles for stars loaded from 'mass'
# 2026-02-02 10:45:52,991 - rubix - DEBUG - 994189 particles for stars loaded from 'metals'
# 2026-02-02 10:45:53,014 - rubix - DEBUG - 994189 particles for stars loaded from 'pos'
# 2026-02-02 10:45:53,034 - rubix - DEBUG - 994189 particles for stars loaded from 'vel'
# 2026-02-02 10:45:53,037 - rubix - DEBUG - 698329 particles for gas loaded from 'rho'
# 2026-02-02 10:45:53,039 - rubix - DEBUG - 698329 particles for gas loaded from 'temp'
# 2026-02-02 10:45:53,042 - rubix - DEBUG - 698329 particles for gas loaded from 'metals'
# 2026-02-02 10:45:53,044 - rubix - DEBUG - 698329 particles for gas loaded from 'metals'
# 2026-02-02 10:45:53,057 - rubix - DEBUG - 698329 particles for gas loaded from 'pos'
# 2026-02-02 10:45:53,070 - rubix - DEBUG - 698329 particles for gas loaded from 'vel'
# 2026-02-02 10:45:53,072 - rubix - DEBUG - 698329 particles for gas loaded from 'mass'
# 2026-02-02 10:45:53,073 - rubix - WARNING - Field 'sfr' -> 'sfr' not found for gas. Assigning zeros.
# 2026-02-02 10:45:53,074 - rubix - WARNING - Field 'internal_energy' -> 'u' not found for gas. Assigning zeros.
# 2026-02-02 10:45:53,076 - rubix - WARNING - Field 'electron_abundance' -> 'electron_abundance' not found for gas. Assigning zeros.
# 2026-02-02 10:45:53,106 - rubix - DEBUG - 698329 particles for gas loaded from 'HI'
# 2026-02-02 10:45:53,131 - rubix - DEBUG - 698329 particles for gas loaded from 'OxMassFrac'
# 2026-02-02 10:45:53,136 - rubix - INFO - Metals assigned to gas particles.
# 2026-02-02 10:45:53,137 - rubix - INFO - Metals shape is: (698329, 10)
# 2026-02-02 10:45:53,679 - rubix - INFO - Simulation snapshot and halo data loaded successfully for classes: ['stars', 'gas'].
# 2026-02-02 10:45:53,696 - rubix - DEBUG - Converting to Rubix format..
# 2026-02-02 10:45:53,753 - rubix - INFO - Half-mass radius calculated: 0.76 kpc
# 2026-02-02 10:45:53,755 - rubix - INFO - Rubix file saved at output/rubix_galaxy.h5
# 2026-02-02 10:45:53,756 - rubix - DEBUG - Creating Rubix file at path: output/rubix_galaxy.h5
# 2026-02-02 10:45:53,767 - rubix - DEBUG - Converting redshift for galaxy data into
# 2026-02-02 10:45:53,769 - rubix - DEBUG - Converting center for galaxy data into kpc
# 2026-02-02 10:45:53,770 - rubix - DEBUG - Converting halfmassrad_stars for galaxy data into kpc
# 2026-02-02 10:45:53,772 - rubix - DEBUG - Converting age for particle type stars into Gyr
# 2026-02-02 10:45:53,775 - rubix - DEBUG - Converting mass for particle type stars into Msun
# 2026-02-02 10:45:53,777 - rubix - DEBUG - Converting metallicity for particle type stars into
# 2026-02-02 10:45:53,780 - rubix - DEBUG - Converting coords for particle type stars into kpc
# 2026-02-02 10:45:53,788 - rubix - DEBUG - Converting velocity for particle type stars into km/s
# 2026-02-02 10:45:53,796 - rubix - DEBUG - Converting density for particle type gas into Msun/kpc^3
# 2026-02-02 10:45:53,799 - rubix - DEBUG - Converting temperature for particle type gas into K
# 2026-02-02 10:45:53,802 - rubix - DEBUG - Converting metals for particle type gas into
# 2026-02-02 10:45:53,811 - rubix - DEBUG - Converting metallicity for particle type gas into
# 2026-02-02 10:45:53,814 - rubix - DEBUG - Converting coords for particle type gas into kpc
# 2026-02-02 10:45:53,820 - rubix - DEBUG - Converting velocity for particle type gas into km/s
# 2026-02-02 10:45:53,825 - rubix - DEBUG - Converting mass for particle type gas into Msun
# 2026-02-02 10:45:53,828 - rubix - DEBUG - Converting sfr for particle type gas into Msun/yr
# 2026-02-02 10:45:53,831 - rubix - DEBUG - Converting internal_energy for particle type gas into erg/g
# 2026-02-02 10:45:53,833 - rubix - DEBUG - Converting electron_abundance for particle type gas into
# 2026-02-02 10:45:53,852 - rubix - INFO - Rubix file saved at output/rubix_galaxy.h5
# 2026-02-02 10:45:53,918 - rubix - INFO - Centering stars particles
# Converted to Rubix format!
# 2026-02-02 10:45:54,503 - rubix - INFO - Data loaded with 994189 star particles and 0 gas particles.
# 2026-02-02 10:45:54,505 - rubix - INFO - Setting up the pipeline...
# 2026-02-02 10:45:54,505 - rubix - DEBUG - Pipeline Configuration: {'Transformers': {'rotate_galaxy': {'name': 'rotate_galaxy', 'depends_on': None, 'args': [], 'kwargs': {}}, 'filter_particles': {'name': 'filter_particles', 'depends_on': 'rotate_galaxy', 'args': [], 'kwargs': {}}, 'spaxel_assignment': {'name': 'spaxel_assignment', 'depends_on': 'filter_particles', 'args': [], 'kwargs': {}}, 'calculate_datacube_particlewise': {'name': 'calculate_datacube_particlewise', 'depends_on': 'spaxel_assignment', 'args': [], 'kwargs': {}}, 'convolve_psf': {'name': 'convolve_psf', 'depends_on': 'calculate_datacube_particlewise', 'args': [], 'kwargs': {}}, 'convolve_lsf': {'name': 'convolve_lsf', 'depends_on': 'convolve_psf', 'args': [], 'kwargs': {}}, 'apply_noise': {'name': 'apply_noise', 'depends_on': 'convolve_lsf', 'args': [], 'kwargs': {}}}}
# 2026-02-02 10:45:54,506 - rubix - DEBUG - Roataion Type found: matrix
# 2026-02-02 10:45:54,508 - rubix - INFO - Calculating spatial bin edges...
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:45:55,256 - rubix - INFO - Getting cosmology...
# 2026-02-02 10:45:55,749 - rubix - INFO - Calculating spatial bin edges...
# 2026-02-02 10:45:55,759 - rubix - INFO - Getting cosmology...
# 2026-02-02 10:45:56,274 - rubix - DEBUG - Method not defined, using default method: cubic
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:45:56,902 - rubix - DEBUG - SSP Wave: (20356,)
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:45:56,930 - rubix - INFO - Getting cosmology...
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:45:57,477 - rubix - DEBUG - Method not defined, using default method: cubic
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:45:58,289 - rubix - INFO - Assembling the pipeline...
# 2026-02-02 10:45:58,290 - rubix - INFO - Compiling the expressions...
# 2026-02-02 10:45:58,291 - rubix - INFO - Number of devices: 8
# 2026-02-02 10:45:58,575 - rubix - INFO - Rotating galaxy with alpha=0.0, beta=0.0, gamma=0.0
# 2026-02-02 10:45:58,576 - rubix - DEBUG - Rotation type is matrix, loading rotation matrix from file.
# 2026-02-02 10:45:58,577 - rubix - INFO - Using rotation matrix from file: JitTracer<float32[3,3]>.
# 2026-02-02 10:45:58,826 - rubix - INFO - Filtering particles outside the aperture...
# 2026-02-02 10:45:58,833 - rubix - INFO - Assigning particles to spaxels...
# 2026-02-02 10:45:58,866 - rubix - INFO - Calculating Data Cube (combined per‐particle)…
# 2026-02-02 10:45:59,018 - rubix - DEBUG - Datacube shape: (300, 300, 3721)
# 2026-02-02 10:45:59,018 - rubix - INFO - Convolving with PSF...
# 2026-02-02 10:45:59,022 - rubix - INFO - Convolving with LSF...
# 2026-02-02 10:45:59,028 - rubix - INFO - Applying noise to datacube with signal to noise ratio: 100 and noise distribution: normal
# 2026-02-02 10:46:10,507 - rubix - INFO - Pipeline run completed in 16.00 seconds.

# %%
#print(rubixdata)

# %% [markdown]
# ## Convert luminosity to flux

# %%
from rubix.spectra.ifu import convert_luminoisty_to_flux
from rubix.cosmology import PLANCK15

observation_lum_dist = PLANCK15.luminosity_distance_to_z(config_NIHAO["galaxy"]["dist_z"])
observation_z = config_NIHAO["galaxy"]["dist_z"]
pixel_size = 1.0
fluxcube = convert_luminoisty_to_flux(rubixdata, observation_lum_dist, observation_z, pixel_size)
rubixdata = fluxcube/1e-20

# %% [markdown]
# ## Store datacube in a fits file with header

# %%
#NBVAL_SKIP
from rubix.core.fits import store_fits

#if config_illustris["telescope"]["name"] == "MUSE_ultraWFM":
#    cutted_datatcube = data.stars.datacube[300:600, :, :]
#    data.stars.datacube = cutted_datatcube
#if config_illustris["telescope"]["name"] == "MUSE_WFM":
#    cutted_datatcube = data.stars.datacube[100:200, :, :]
#    data.stars.datacube = cutted_datatcube

#store_fits(config_NIHAO, rubixdata, "./output/emiles/")

# %% [markdown]
# ## Step 4: Mock-data
#
# Now we have our final datacube and can use the mock-data to do science. Here we have a quick look in the optical wavelengthrange of the mock-datacube and show the spectra of a central spaxel and a spatial image.

# %%
#NBVAL_SKIP
import jax.numpy as jnp

wave = pipe.telescope.wave_seq
# get the indices of the visible wavelengths of 4000-8000 Angstroms
visible_indices = jnp.where((wave >= 4000) & (wave <= 8000))

# %%
#NBVAL_SKIP
import numpy as np
# get the spectra of the visible wavelengths from the ifu cube
#visible_spectra = rubixdata.stars.datacube[ :, :, visible_indices[0]]
#visible_spectra = rubixdata[ :, :, visible_indices[0]]
sharded_visible_spectra = rubixdata[ :, :, visible_indices[0]]
#visible_spectra.shape

#image = jnp.sum(visible_spectra, axis=2)
sharded_image = jnp.sum(sharded_visible_spectra, axis=2)
img32 = np.array(sharded_image, dtype=np.float32)

# Plot side by side
plt.figure(figsize=(6, 5))

# Original IFU datacube image
#im0 = axes[0].imshow(image, origin="lower", cmap="inferno")
#axes[0].set_title("Original IFU Datacube")
#fig.colorbar(im0, ax=axes[0])

# Sharded IFU datacube image
plt.imshow(img32, origin="lower", cmap="inferno")
plt.title("Sharded IFU Datacube")
plt.colorbar(label="Flux [erg/s/cm^2]")

plt.tight_layout()
plt.savefig(f"./output/emiles/image_{galaxy_id}_{component}.jpeg")
plt.show()

# %%
#NBVAL_SKIP
wave = pipe.telescope.wave_seq

#spectra = rubixdata#.stars.datacube # Spectra of all stars
spectra_sharded = rubixdata # Spectra of all stars
#print(spectra.shape)

plt.figure(figsize=(10, 5))
#plt.subplot(1, 2, 1)
#plt.title("Rubix")
#plt.xlabel("Wavelength [Angstrom]")
#plt.ylabel("Flux [erg/s/cm^2/Angstrom]")
#plt.plot(wave, spectra[12,12,:])
#plt.plot(wave, spectra[8,12,:])

#plt.subplot(1, 2, 2)
plt.title("Rubix Sharded")
plt.xlabel("Wavelength [Angstrom]")
plt.ylabel("Flux [erg/s/cm^2/Angstrom]")
plt.plot(wave, spectra_sharded[150,150,:])
plt.plot(wave, spectra_sharded[150,200,:])
plt.plot(wave, spectra_sharded[200,150,:])

plt.savefig(f"./output/emiles/spectra_{galaxy_id}_{component}.jpeg")
plt.show()

# %% [markdown]
# ## DONE!
#
# Congratulations, you have sucessfully run the RUBIX pipeline to create your own mock-observed IFU datacube! Now enjoy playing around with the RUBIX pipeline and enjoy doing amazing science with RUBIX :)

# %%
# NBVAL_SKIP
from rubix.core.rotation import get_galaxy_rotation
rotate = get_galaxy_rotation(config_NIHAO)

inputdata = rotate(inputdata)
# Out:
# 2026-02-02 10:49:43,836 - rubix - DEBUG - Roataion Type found: matrix
# 2026-02-02 10:49:43,838 - rubix - INFO - Rotating galaxy with alpha=0.0, beta=0.0, gamma=0.0
# 2026-02-02 10:49:43,839 - rubix - DEBUG - Rotation type is matrix, loading rotation matrix from file.
# 2026-02-02 10:49:43,850 - rubix - INFO - Using rotation matrix from file: [[ 0.9997989   0.00117076 -0.02002094]
#  [ 0.02005514 -0.05836516  0.99809384]
#  [ 0.         -0.9982946  -0.05837689]].

# %%
from rubix.core.telescope import get_spaxel_assignment
bin_particles = get_spaxel_assignment(config_NIHAO)

inputdata = bin_particles(inputdata)
# Out:
# /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/factory.py:26: UserWarning: No telescope config provided, using default stored in /home/annalena/.conda/envs/rubix/lib/python3.12/site-packages/rubix/telescope/telescopes.yaml
#   warnings.warn(
# 2026-02-02 10:49:44,378 - rubix - INFO - Calculating spatial bin edges...
# 2026-02-02 10:49:44,387 - rubix - INFO - Getting cosmology...
# 2026-02-02 10:49:44,392 - rubix - INFO - Assigning particles to spaxels...

# %%
# NBVAL_SKIP
import numpy as np
import matplotlib.pyplot as plt

# Assuming your data arrays are defined as follows:
pixel_assignment = np.asarray(np.squeeze(inputdata.stars.pixel_assignment))
velocities = np.asarray(inputdata.stars.velocity[:, 2])

# Compute the sum of velocities and count per pixel using np.bincount
sum_velocity = np.bincount(pixel_assignment, weights=velocities)
counts = np.bincount(pixel_assignment)

# Calculate mean velocity; note: division by zero is avoided if every pixel has at least one star.
mean_velocity = sum_velocity / counts


# If you know the pixel grid dimensions (for example, a square grid)
n_pixels = len(mean_velocity)
grid_size = int(np.sqrt(n_pixels))
if grid_size * grid_size != n_pixels:
    raise ValueError("The total number of pixels is not a perfect square; please specify the grid shape explicitly.")

# Reshape the mean_velocity into a 2D array for imshow
velocity_map = mean_velocity.reshape((grid_size, grid_size))
print(velocity_map[12,12])

print(velocity_map[17,12]-velocity_map[7,12])
# Plot the result
plt.figure(figsize=(6, 5))
plt.imshow(velocity_map, origin='lower', interpolation='nearest', cmap='seismic')
plt.colorbar(label='Mean Velocity')
plt.title('Mean Velocity per Pixel')
plt.xlabel('X pixel index')
plt.ylabel('Y pixel index')
#storepath = f"./output/datacube_NIHAO{config_illustris['data']['load_galaxy_args']['id']}_{config_illustris["telescope"]["name"]}_{config_illustris['pipeline']['name']}_velocity.png"
#plt.savefig(storepath)
plt.savefig(f"./output/emiles/mean_vel_{galaxy_id}_{component}.jpeg")
plt.show()
# Out:
# /tmp/ipykernel_19807/2343321222.py:14: RuntimeWarning: invalid value encountered in divide
#   mean_velocity = sum_velocity / counts
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 21
#      19 grid_size = int(np.sqrt(n_pixels))
#      20 if grid_size * grid_size != n_pixels:
# ---> 21     raise ValueError("The total number of pixels is not a perfect square; please specify the grid shape explicitly.")
#      23 # Reshape the mean_velocity into a 2D array for imshow
#      24 velocity_map = mean_velocity.reshape((grid_size, grid_size))
#
# ValueError: The total number of pixels is not a perfect square; please specify the grid shape explicitly.

# %%
# NBVAL_SKIP
import numpy as np
import matplotlib.pyplot as plt

# Assuming your data arrays are defined as follows:
pixel_assignment = np.asarray(np.squeeze(inputdata.stars.pixel_assignment))
ages = np.asarray(inputdata.stars.age[:])

# Compute the sum of velocities and count per pixel using np.bincount
sum_ages = np.bincount(pixel_assignment, weights=ages)
counts = np.bincount(pixel_assignment)

# Calculate mean velocity; note: division by zero is avoided if every pixel has at least one star.
mean_age = sum_ages / counts


# If you know the pixel grid dimensions (for example, a square grid)
n_pixels = len(mean_age)
grid_size = int(np.sqrt(n_pixels))
if grid_size * grid_size != n_pixels:
    raise ValueError("The total number of pixels is not a perfect square; please specify the grid shape explicitly.")

# Reshape the mean_velocity into a 2D array for imshow
age_map = mean_age.reshape((grid_size, grid_size))
print(age_map[12,12])

# Plot the result
plt.figure(figsize=(6, 5))
plt.imshow(age_map, origin='lower', interpolation='nearest', cmap='inferno')
plt.colorbar(label='Mean Age')
plt.title('Mean Age per Pixel')
plt.xlabel('X pixel index')
plt.ylabel('Y pixel index')
#storepath = f"./output/datacube_NIHAO{config_illustris['data']['load_galaxy_args']['id']}_{config_illustris["telescope"]["name"]}_{config_illustris['pipeline']['name']}_age.png"
#plt.savefig(storepath)
plt.savefig(f"./output/emiles/mean_age_{galaxy_id}_{component}.jpeg")
plt.show()
# Out:
# /tmp/ipykernel_921281/2773981002.py:14: RuntimeWarning: invalid value encountered in divide
#   mean_age = sum_ages / counts
# nan

# %%
# NBVAL_SKIP
import matplotlib.pyplot as plt

# Plot a histogram of the velocities
plt.hist(inputdata.stars.age[:], bins=30, edgecolor='black')
plt.xlabel('Age (Gyr)')
plt.ylabel('Frequency')
plt.title('Histogram of Star Ages')
plt.savefig(f"./output/emiles/age_{galaxy_id}_{component}.jpeg")
plt.show()

# %%
# NBVAL_SKIP
import matplotlib.pyplot as plt

# Plot a histogram of the velocities
plt.hist(inputdata.stars.metallicity[:], bins=30, edgecolor='black')
plt.xlabel('Metallicity (Z/Zsun)')
plt.ylabel('Frequency')
plt.title('Histogram of Star Metallicity')
plt.savefig(f"./output/emiles/metallicity_{galaxy_id}_{component}.jpeg")
plt.show()
